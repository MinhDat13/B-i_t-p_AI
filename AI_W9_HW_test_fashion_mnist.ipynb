# %% [markdown]
# <a href="https://colab.research.google.com/github/MinhDat13/Bai_tap_AI/blob/main/AI_W9_HW_test_fashion_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import load_img, img_to_array
from keras.models import load_model
img=load_img('giay.jpg',grayscale=True,target_size=(28,28))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,28*28)
img=img.astype('float32')
img=img/255
model=load_model('/content/drive/MyDrive/Data_AI/fashion.h5')
np.argmax(model.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 160ms/step
# array([8])
